# %% [markdown]
# # Python Programming/Errors

# %% [markdown]
# https://en.wikibooks.org/wiki/Python_Programming/Errors#:~:text=In%20python%20there%20are%20three,errors%2C%20logic%20errors%20and%20exceptions.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# https://www.geeksforgeeks.org/errors-and-exceptions-in-python/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)
#
# ![image.png](attachment:image-3.png)
#
# ![image.png](attachment:image-4.png)
#
# ![image.png](attachment:image-5.png)

# %%
try:
    a=10
    b=0
    c = a/b
    print(c)
except:
    print("cant divide with zero")
# Out:
# cant divide with zero

# %%
try:
    f= open("text.txt", "r")
    f.write("ineuron")
except:
    print("there is a mistake")
print("this is the outer block")
# Out:
# there is a mistake
# this is the outer block

# %%
import random
l2 = random.sample(range(1,10),9)

# %%
try:
    for i in range(len(l2)):
        print(l2[i])
except:
    print(" this is not working")
# Out:
# 7
# 8
# 1
# 5
# 4
# 6
# 2
# 3
# 9

# %%
import sys
randomlist = ["a", 8,0,"6",4,5,"a"]

for entry in randomlist:
    try:
        print("The entry is ->" , entry)
        r= 1/ int(entry)
        print("The reciprocal of ", entry ,"is", r)
        print("---- next entry ----")
        #break
    except:
        print("*************oops", sys.exc_info()[0], "occured***************")
        print("---- next entry ----")
# Out:
# The entry is -> a
# *************oops <class 'ValueError'> occured***************
# ---- next entry ----
# The entry is -> 8
# The reciprocal of  8 is 0.125
# ---- next entry ----
# The entry is -> 0
# *************oops <class 'ZeroDivisionError'> occured***************
# ---- next entry ----
# The entry is -> 6
# The reciprocal of  6 is 0.16666666666666666
# ---- next entry ----
# The entry is -> 4
# The reciprocal of  4 is 0.25
# ---- next entry ----
# The entry is -> 5
# The reciprocal of  5 is 0.2
# ---- next entry ----
# The entry is -> a
# *************oops <class 'ValueError'> occured***************
# ---- next entry ----

# %%
try:
    #block of code
except:
    # block of code
else:
    # this will execute when exception didnt occure
# Out:
#   Input In [1]
#     except:
#     ^
# IndentationError: expected an indented block

# %%
try: 
    num = int (input("enter a number:   "))
    assert num%2 ==0
except:
    print(" not an even number ")

else:
    reciprocal = 1/num
    print(reciprocal)
# Out:
# 0.125

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# #### Finaly - this block of code will always be executed

# %%
try :
    a = int(input("enter value of a: "))
    b = int(input(" enter value of b: "))
    c = a/b
    print(" answer", c)
except ZeroDivisionError:
    print(" canot divide by zero")
finally:
    print(" from finally block ")
# Out:
#  answer 0.8333333333333334
#  from finally block

# %%
def divide (x,y):
    try:
        print(x/y)
    except ZeroDivisionError as e:
        print(e)

# %%
divide(1,0)
divide(2,4)
# Out:
# division by zero
# 0.5
