# %% [markdown]
# # Logging and Debugging

# %% [markdown]
# https://www.geeksforgeeks.org/logging-in-python/
#
# ![image.png](attachment:image.png)

# %%
def add(x,y):
    return x+y
def substract(x,y):
    return x-y

def multiply(x,y):
    return x*y

def divide(x,y):
    if y>0:
        return x/y
    else:
        return "Cant divide by zero"


num1 = 10
num2 = 20

print( add(num1, num2))
print( substract(num1, num2))
print( multiply(num1, num2))
print( divide(num1, num2))
# Out:
# 30
# -10
# 200
# 0.5

# %%
import logging

logging.basicConfig(filename = "test2.log",level = logging.INFO)


def add(x,y):
    return x+y
    
def substract(x,y):
    return x-y

def multiply(x,y):
    return x*y

def divide(x,y):
    if y>0:
        return x/y
    else:
        return "Cant divide by zero"


num1 = 10
num2 = 20

logging.debug( add(num1, num2))
logging.debug( substract(num1, num2))
logging.debug( multiply(num1, num2))
logging.debug( divide(num1, num2))

# %% [markdown]
# 1. DEbugg Level -10
# 2. Info level - will collect all information -20
# 3. Warnining -30
# 4. Error -40
# 5. Critical -50

# %% [markdown]
# https://medium.com/@techfossguru/ultimate-guide-to-learn-python-logging-module-in-depth-tutorial-6f7e642e73e1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing module
import logging

# Create and configure logger
logging.basicConfig(filename="newfile1.log",
					format='%(asctime)s %(message)s',
					filemode='w')

# Creating an object
logger = logging.getLogger()

# Setting the threshold of logger to DEBUG
logger.setLevel(logging.DEBUG)

# Test messages
logger.debug("Harmless debug Message")
logger.info("Just an information")
logger.warning("Its a Warning")
logger.error("Did you try to divide by zero")
logger.critical("Internet is down")
