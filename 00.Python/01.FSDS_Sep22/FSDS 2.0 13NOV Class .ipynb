# %%
def test1(func):
    def test2():
        print(" I am inside test2")
        func()
        print(func())
        print(" function executed")
        return func()
    return test2

# %%
@test1
def test3():
    print(" this is my test 3")

# %%
test3()
# Out:
#  I am inside test2
#  this is my test 3
#  this is my test 3
# None
#  function executed
#  this is my test 3

# %%
test1(test3())
# Out:
#  I am inside test2
#  this is my test 3
#  this is my test 3
# None
#  function executed
#  this is my test 3
# <function __main__.test1.<locals>.test2()>

# %%
# in this case print is not used, instead return is used.
@test1
def test4():
    return 5+6

# %%
test4()
# Out:
#  I am inside test2
# 11
#  function executed
# 11

# %%
a = test4()
# Out:
#  I am inside test2
# 11
#  function executed

# %%
a
# Out:
# 11

# %%
print(a)
# Out:
# 11

# %%
test4() + 12
# Out:
#  I am inside test2
# 11
#  function executed
# 23

# %%
def test5():
    return 5+4

# %%
type(test5())
# Out:
# int

# %%
type(test4())
# Out:
#  I am inside test2
# 11
#  function executed
# int

# %%
def test6(func):
    def test7():
        func()
        print(func())
        print(" this is my decorator function")
    return test7

# %%
def test8():
    return 5+7

# %%
test8()+12
# Out:
# 24

# %%
@test6
def test8():
    return 5+7

# %%
test8()
# Out:
# 12
#  this is my decorator function

# %%
type(test8())
# Out:
# 12
#  this is my decorator function
# NoneType

# %%
test8 () +12
# Out:
# 12
#  this is my decorator function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 test8 () +12
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
def test6(func):
    def test7():
        func()
        print(func())
        print(" this is my decorator function")
        return func()
    return test7

# %%
@test6
def test8():
    return 9+10

# %%
test8() +12
# Out:
# 19
#  this is my decorator function
# 31

# %%
test8()
# Out:
# 19
#  this is my decorator function
# 19

# %%
def test8(a,b):
    return a+b

# %%
test8("manu", "madhav")
# Out:
# 'manumadhav'

# %%
@test6
def test8(a,b):
    return a+b

# %%
test8("manu", "madhav")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 test8("manu", "madhav")
#
# TypeError: test6.<locals>.test7() takes 0 positional arguments but 2 were given

# %%
def test6(func):
    def test7(a,b):
        func(a,b)
        print(func(a,b))
        print(" this is my decorator function")
        return func(a,b)
    return test7

# %%
@test6
def test8(a,b):
    return a+b

# %%
test8("manu", "madhav")
# Out:
# manumadhav
#  this is my decorator function
# 'manumadhav'

# %%
@test6
def test8(a,b):
    return a+b+c

# %%
test8("manu", "madhav")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 test8("manu", "madhav")
#
# Cell In[29], line 3, in test6.<locals>.test7(a, b)
#       2 def test7(a,b):
# ----> 3     func(a,b)
#       4     print(func(a,b))
#       5     print(" this is my decorator function")
#
# Cell In[32], line 3, in test8(a, b)
#       1 @test6
#       2 def test8(a,b):
# ----> 3     return a+b+c
#
# NameError: name 'c' is not defined

# %% [markdown]
# 1. this is an issue in regular development

# %%
def test6(func):
    def test7(*args):
        func(*args)
        print(func(*args))
        print(" this is my decorator function")
        return func(*args)
    return test7

# %%
@test6
def test8(a,b,c):
    return a+b+c

# %%
test8("manu", "madhav","manu")
# Out:
# manumadhavmanu
#  this is my decorator function
# 'manumadhavmanu'

# %%
def test6(func):
    def test7(*args, **kwargs):
        func(*args, **kwargs)
        print(func(*args, **kwargs))
        print(" this is my decorator function")
        return func(*args, **kwargs)
    return test7

# %%
@test6
def test9(**kwargs):
    
    sum = 0
    for i in kwargs:
        sum = i+sum
    return sum

# %%
test9(a=89, b=34)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 test9(a=89, b=34)
#
# Cell In[37], line 3, in test6.<locals>.test7(*args, **kwargs)
#       2 def test7(*args, **kwargs):
# ----> 3     func(*args, **kwargs)
#       4     print(func(*args, **kwargs))
#       5     print(" this is my decorator function")
#
# Cell In[38], line 6, in test9(**kwargs)
#       4 sum = 0
#       5 for i in kwargs:
# ----> 6     sum = i+sum
#       7 return sum
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# defining a decorator
def hello_decorator(func):
	
	# inner1 is a Wrapper function in
	# which the argument is called
		
	# inner function can access the outer local
	# functions like in this case "func"
	def inner1():
		print("Hello, this is before function execution")
	
		# calling the actual function now
		# inside the wrapper function.
		func()
	
		print("This is after function execution")
			
	return inner1
	
	
# defining a function, to be called inside wrapper
def function_to_be_used():
	print("This is inside the function !!")
	
	
# passing 'function_to_be_used' inside the
# decorator to control its behavior
function_to_be_used = hello_decorator(function_to_be_used)
	
	
# calling the function
function_to_be_used()
# Out:
# Hello, this is before function execution
# This is inside the function !!
# This is after function execution

# %%
import time


def timeis(func):
	'''Decorator that reports the execution time.'''

	def wrap(*args, **kwargs):
		start = time.time()
		result = func(*args, **kwargs)
		end = time.time()
		
		print(func.__name__, end-start)
		return result
	return wrap

@timeis
def countdown(n):
	'''Counts down'''
	while n > 0:
		n -= 1

countdown(5)
countdown(100000)
countdown(10000000)
countdown(100000000)
# Out:
# countdown 0.0
# countdown 0.013950824737548828
# countdown 0.8948278427124023
# countdown 8.062225103378296

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Anonymous Function

# %%
def test10(a,b):
    return a+b

# %%
test10("manu","madhav")
# Out:
# 'manumadhav'

# %%
lambda a,b: a+b
# Out:
# <function __main__.<lambda>(a, b)>

# %%
c = lambda a,b: a+b

# %%
c("manu", " madhav")
# Out:
# 'manu madhav'

# %%
d = lambda a,b,c,d: (a*b+c)/d

# %%
d(10,12,14,15)
# Out:
# 8.933333333333334

# %%
e = lambda *args : args*args

# %%
e(10,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 e(10,10)
#
# Cell In[54], line 1, in <lambda>(*args)
# ----> 1 e = lambda *args : args*args
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %% [markdown]
# https://betterprogramming.pub/lambda-map-and-filter-in-python-4935f248593
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.geeksforgeeks.org/python-lambda-anonymous-functions-filter-map-reduce/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image.png](attachment:image-2.png)

# %%
is_even_list = [lambda arg=x: arg * 10 for x in range(1, 5)]

# iterate on each lambda function
# and invoke the function to get the calculated value
for item in is_even_list:
	print(item())
# Out:
# 10
# 20
# 30
# 40

# %%
# Example of lambda function using if-else
Max = lambda a, b : a if(a > b) else b

print(Max(1, 2))
# Out:
# 2

# %%
List = [[2,3,4],[1, 4, 16, 64],[3, 6, 9, 12]]

# Sort each sublist
sortList = lambda x: (sorted(i) for i in x)

# Get the second largest element
secondLargest = lambda x, f : [y[len(y)-2] for y in f(x)]
res = secondLargest(List, sortList)

print(res)
# Out:
# [3, 16, 9]

# %% [markdown]
# ## Using lambda() Function with filter()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61]

final_list = list(filter(lambda x: (x % 2 != 0), li))
print(final_list)
# Out:
# [5, 7, 97, 77, 23, 73, 61]

# %%
# Python 3 code to people above 18 yrs
ages = [13, 90, 17, 59, 21, 60, 5]

adults = list(filter(lambda age: age > 18, ages))

print(adults)
# Out:
# [90, 59, 21, 60]

# %% [markdown]
# ## Using lambda() Function with map()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python code to illustrate
# map() with lambda()
# to get double of a list.
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61]

final_list = list(map(lambda x: x*2, li))
print(final_list)
# Out:
# [10, 14, 44, 194, 108, 124, 154, 46, 146, 122]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python program to demonstrate
# use of lambda() function
# with map() function
animals = ['dog', 'cat', 'parrot', 'rabbit']

# here we intend to change all animal names
# to upper case and return the same
uppered_animals = list(map(lambda animal: animal.upper(), animals))

print(uppered_animals)
# Out:
# ['DOG', 'CAT', 'PARROT', 'RABBIT']

# %% [markdown]
# # Map

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l = [1,2,3,4,5,6,7,8]

# %%
def test14(x):
    return x+10

# %%
list(map(test14,l))
# Out:
# [11, 12, 13, 14, 15, 16, 17, 18]

# %%
#alternative option.

list(map(lambda a: a+10 , l))
# Out:
# [11, 12, 13, 14, 15, 16, 17, 18]

# %%
l2 = ["manu", "madhav","suja"]

# %%
list(map(lambda x: x.upper(),l2))
# Out:
# ['MANU', 'MADHAV', 'SUJA']

# %%
list(map(str.upper, l2))
# Out:
# ['MANU', 'MADHAV', 'SUJA']

# %%
list(map(len, l2))
# Out:
# [4, 6, 4]

# %% [markdown]
# # Filter

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l =[1,2,3,4,5,6,6]

# %%
list(filter(lambda x : x%2 ==0, l))
# Out:
# [2, 4, 6, 6]

# %%
[i for i in l if i%2 ==0]
# Out:
# [2, 4, 6, 6]

# %%
def test24(a):
    l =[]
    for i in a:
        if i%2 == 0:
            l.append(i)
    return l

# %%
test24(l)
# Out:
# [2, 4, 6, 6]

# %%
a = lambda a:a if a%2 ==0 else None

# %%
list(map(a,l))
# Out:
# [None, 2, None, 4, None, 6, 6]

# %% [markdown]
# ### Note: Filter always working on boolean value

# %%
def test25(a):
    if a%2 == 0:
        return True
    else:
        return False

# %%
list(filter(test25, l))
# Out:
# [2, 4, 6, 6]

# %%
def test25(a):
    if a%2 == 0:
        return False # interchanged
    else:
        return True

# %%
list(filter(test25, l))
# Out:
# [1, 3, 5]

# %% [markdown]
# # Reduce

# %%
from functools import reduce
import random

# %%
l = random.sample(range(1, 10),9)
l
# Out:
# [3, 8, 7, 6, 5, 1, 9, 4, 2]

# %%
reduce(lambda a,b: a*b, l)
# Out:
# 362880

# %% [markdown]
# https://www.geeksforgeeks.org/reduce-in-python/
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# python code to demonstrate working of reduce()

# importing functools for reduce()
import functools

# initializing list
lis = [1, 3, 5, 6, 2]

# using reduce to compute sum of list
print("The sum of the list elements is : ", end="")
print(functools.reduce(lambda a, b: a+b, lis))

# using reduce to compute maximum element from list
print("The maximum element of the list is : ", end="")
print(functools.reduce(lambda a, b: a if a > b else b, lis))
# Out:
# The sum of the list elements is : 17
# The maximum element of the list is : 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# python code to demonstrate working of reduce()
# using operator functions

# importing functools for reduce()
import functools

# importing operator for operator functions
import operator

# initializing list
lis = [1, 3, 5, 6, 2]

# using reduce to compute sum of list
# using operator functions
print("The sum of the list elements is : ", end="")
print(functools.reduce(operator.add, lis))

# using reduce to compute product
# using operator functions
print("The product of list elements is : ", end="")
print(functools.reduce(operator.mul, lis))

# using reduce to concatenate string
print("The concatenated product is : ", end="")
print(functools.reduce(operator.add, ["geeks", "for", "geeks"]))
# Out:
# The sum of the list elements is : 17
# The product of list elements is : 180
# The concatenated product is : geeksforgeeks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# python code to demonstrate summation
# using reduce() and accumulate()

# importing itertools for accumulate()
import itertools

# importing functools for reduce()
import functools

# initializing list
lis = [1, 3, 4, 10, 4]

# printing summation using accumulate()
print("The summation of list using accumulate is :", end="")
print(list(itertools.accumulate(lis, lambda x, y: x+y)))

# printing summation using reduce()
print("The summation of list using reduce is :", end="")
print(functools.reduce(lambda x, y: x+y, lis))
# Out:
# The summation of list using accumulate is :[1, 4, 8, 18, 22]
# The summation of list using reduce is :22

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Python program to illustrate sum of two numbers.
def reduce(function, iterable, initializer=None):
	it = iter(iterable)
	if initializer is None:
		value = next(it)
	else:
		value = initializer
	for element in it:
		value = function(value, element)
	return value

# Note that the initializer, when not None, is used as the first value instead of the first value from iterable , and after the whole iterable.
tup = (2,1,0,2,2,0,0,2)
print(reduce(lambda x, y: x+y, tup,6))

# This code is contributed by aashutoshjha
# Out:
# 15

# %%
reduce(lambda a,b: a*b, l)

# %%
reduce (lambda a,b,c: a*b*c , l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 reduce (lambda a,b,c: a*b*c , l)
#
# Cell In[51], line 9, in reduce(function, iterable, initializer)
#       7 	value = initializer
#       8 for element in it:
# ----> 9 	value = function(value, element)
#      10 return value
#
# TypeError: <lambda>() missing 1 required positional argument: 'c'

# %% [markdown]
# #### due to above reason when ever we pass an argument in reduce , it should be 2 in number as it will work fine in default.

# %%
l2 =[3]

# %%
reduce(lambda a,b : a*b , l2) # this is the only exception in reduce
# Out:
# 3

# %%
def test26() -> int: # ->  hint to a programmer to indicate what type of data needs to be given as output. This is an indication
    """ test info """ # this is doc string about the function
    return "this is my func"

# %%
test26()
# Out:
# 'this is my func'

# %%
def test26(a: int, b) -> int: 
    """ summation """ # this is doc string about the function
    return a+b

# %%
test26(10, 5)
# Out:
# 15

# %%
def test26(a: int, b: "func", c: int = 243) -> int: 
    """ summation """ # this is doc string about the function
    return a+b+str(c)

# %%
test26("manu ", "madhav ")
# Out:
# 'manu madhav 243'
